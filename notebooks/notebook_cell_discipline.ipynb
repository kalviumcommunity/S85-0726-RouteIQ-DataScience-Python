# %% [markdown]
# # Notebook Cell Discipline Demo
#
# This notebook demonstrates clear separation between explanation (Markdown) and execution (Code).

# %% [markdown]
# ## Step 1: Run a simple arithmetic example
#
# The next code cell calculates a sum and prints the result.

# %%
a = 3
b = 5
print("Sum result:", a + b)
# Out:
# Sum result: 8

# %% [markdown]
# ## Step 2: Show basic Python environment details
#
# The next code cell prints the Python version currently used by this notebook kernel.

# %%
import sys
print("Python version:", sys.version.split()[0])
# Out:
# Python version: 3.11.9
